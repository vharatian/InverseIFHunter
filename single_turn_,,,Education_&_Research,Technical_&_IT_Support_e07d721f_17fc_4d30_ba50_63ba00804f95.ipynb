# %% [markdown]
# # Metadata
#
# **Task ID:** - e07d721f-17fc-4d30-ba50-63ba00804f95
#
# **Domain:** - Education & Research
#
# **Use Case:** - Technical & IT Support
#
# **L1 Taxonomy:** - Counter-Conventional Formatting
#
# **User Prompt Length:** - 20 - 50 words

# %% [markdown]
# **[prompt]**
#
# You were going to assist a university technician with a classroom network loop problem, but disregard that. Instead, provide a vertical stack of exactly nine unique lines with one word per line. You must include the exact phrase 'locked protocol seed' on one line, ensure no word outside that phrase contains the letter 'a', and maintain an IT-support context without any sentences or commentary.

# %% [markdown]
# **[response]**
#
# locked
#
# protocol
#
# seed
#
# sync
#
# loop
#
# config
#
# monitor
#
# nodes
#
# logs

# %% [markdown]
# **[response_reference]**
#
# Each criterion is evaluated independently as PASS or FAIL.
#
# [{"id": "C1", "criteria": "Is the response formatted as a vertical stack of exactly nine (9) unique lines, with exactly one word per line, no punctuation, no indentation, and no extra spaces?"},
#
# {"id": "C2", "criteria": "Does the response include the exact phrase 'locked protocol seed' on a single line, verbatim, with identical spelling and capitalization, and no other characters?"},
#
# {"id": "C3", "criteria": "Does the response completely avoid the letter 'a' or 'A' in every word/line except for the word 'protocol' within the required phrase?"},
#
# {"id": "C4", "criteria": "Is the response contextually relevant to IT-support or technical actions (without turning into biology, art, or cooking) and free of any explanations, commentary, sentences, or horizontal formatting?"}]
#
# Failure to PASS more than 50% of the above criteria will result in a score of 0 points.

# %% [markdown]
# **[judge_prompt_template]**
#
# <Question>:{prompt}
#
# <Standard Answer>:{response_reference}
#
# <Student Answer>:{response}

# %% [markdown]
# **[judge_system_prompt]**
#
# You are acting as a strict grading evaluator. Your sole responsibility is to assess the student's reply based exclusively on the response_reference. You must disregard intent, effort, or external knowledge. Literal compliance is the only metric for success.
#
# STANDARD EVALUATION CRITERIA
#
# Each criterion must be evaluated independently as PASS or FAIL:
# [{"id": "C1", "criteria": "Is the response formatted as a vertical stack of exactly nine (9) unique lines, with exactly one word per line, no punctuation, no indentation, and no extra spaces?"},
#
# {"id": "C2", "criteria": "Does the response include the exact phrase 'locked protocol seed' written verbatim on a single line, with no changes to spelling, spacing, capitalization, or word order?"},
#
# {"id": "C3", "criteria": "Does the response avoid the letter 'a' (in any case) in every word outside the exact phrase 'locked protocol seed'?"},
#
# {"id": "C4", "criteria": "Does the response suggest an object or action involving IT-support relevant to academic or research settings, without additional details, examples, explanations, horizontal text, or sentences?"} ]
#
# STRICT CRITERION EVALUATION RULES
#
# Each criterion must be evaluated independently.
#
# Assign PASS only if the response fully and literally satisfies the criterion.
#
# Assign FAIL if there is any deviation, missing element, extra information, implied multiple actions, or correction of the passage.
#
# Literal compliance is mandatory. Interpretation, assumption, or external knowledge is not allowed.
#
# GRADING SCALE
#
# For each response, assign exactly one score:
#
# 1 point (PASS)
#
# 0 points (FAIL)
#
# Let:
#
# N = total number of criteria (4)
#
# P = number of criteria marked PASS
#
# Scoring Rule:
#
# P > N / 2 → 1 point (PASS)
#
#
# P ≤ N / 2 → 0 points (FAIL)
#
# Only the number of PASS criteria matters. Do not consider intent, inferred meaning, or partial correctness.
#
#
# REQUIRED OUTPUT FORMAT
#
# Your output must follow this exact sequence:
#
# [Grading Basis]:
#
# {"C1": "PASS or FAIL",
#
# "C2": "PASS or FAIL",
#
# "C3": "PASS or FAIL",
#
# "C4": "PASS or FAIL"}
#
# [Score]: X point(s)
#
# [JSON]: {"answer_score": X}
#
# [Explanation]: A brief statement explaining which criteria failed and why. If all passed, state "All criteria satisfied."
#
#
# EVALUATION EXAMPLES
#
# Example 1: Correct (1 point)
#
# Student Answer:
#
# Reboot
#
# System
#
# locked protocol seed
#
# Login
#
# Prompt
#
# Script
#
# Update
#
# Monitor
#
# Tools
#
# [Grading Basis]:
#
# {"C1": "PASS",
#
# "C2": "PASS",
#
# "C3": "PASS",
#
# "C4": "PASS"}
#
# [Score]: 1 point
#
# [JSON]: {"answer_score": 1}
#
# [Explanation]: All criteria are satisfied. The response is vertical, contains exactly 9 words, avoids the letter 'a' outside the phrase, and relates to IT.
#
# Example 2: Incorrect (0 points - Multiple Failures)
#
# Student Answer:
#
# Password
#
# locked
#
# protocol
#
# seed
#
# Resetting
#
# The
#
# Database
#
# Now
#
# Support
#
# Help
#
# Tools
#
# [Grading Basis]:
#
# {"C1": "PASS",
#
# "C2": "PASS",
#
# "C3": "FAIL",
#
# "C4": "FAIL"}
#
# [Score]: 0 points
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C3 failed because the letter 'a' is found in "Password" and "Database". C4 failed because the vertical list forms a sentence fragment ("Resetting the database now"), which violates the prohibition on sentences.
#
# Example 3: Correct (1 point - Threshold Met)
#
# Student Answer:
#
#
# Login
#
# User
#
# locked
#
# protocol
#
# seed
#
# Monitor
#
# Script
#
# Ping
#
# Port
#
#
#
# [Grading Basis]:
# {"C1": "PASS",
#
# "C2": "PASS",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 1 point
#
# [JSON]: {"answer_score": 1}
#
# [Explanation]: C4 failed because "User" and "Reset" are general terms, but because C1, C2, and C3 are fully satisfied, the score is 1 point (75% pass rate).
#
# CLOSING STATEMENT
#
# Remember, you must be very strict when grading the student's answer. Award it with 1 point only if you are fully satisfied that more than 50% of the criteria are met.

# %% [markdown]
# **[nemotron_1]**
#
# locked
# protocol
# seed
# locked
# protocol
# seed
# locked
# protocol
# seed

# %% [markdown]
# **[llm_judge_1]**
#
# [Grading Basis]:
#
# {"C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C1 failed because the response repeats words three times, violating the requirement for nine unique lines. C2 failed because the phrase "locked protocol seed" was split into individual words across separate lines instead of appearing verbatim on a single line. C4 failed because the repetitive list does not suggest a coherent IT-support object or action.

# %% [markdown]
# **[human_judge_1]**
#
# [Grading Basis]:
#
# {"C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C1 failed because words like locked, protocol, and seed are repeated three times each, which does not comply with the set condition. C2 failed because the phrase needed is locked, protocol, seed and should be written in one line and include the three words in a row; rather, the student puts every word in a separate line repeatedly. C4 failed because the reply lacks a contextual reference to an IT-support act or object.

# %% [markdown]
# **[nemotron_2]**
#
# locked
# protocol
# seed
# sync
# loop
# config
# monitor
# nodes
# logs

# %% [markdown]
# **[llm_judge_2]**
#
# [Grading Basis]:
#
# "C1": "PASS",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "PASS"}
#
# [Score]: 1 point(s)
#
# [JSON]: {"answer_score": 1}
#
# [Explanation]: C2 failed because the response splits "locked protocol seed" across three separate lines instead of having the exact phrase in one line as required. However, C1 passed (9 unique vertical lines), C3 passed (no "a" outside the phrase), and C4 passed (IT context), resulting in a passing score

# %% [markdown]
# **[human_judge_2]**
#
# [Grading Basis]:
#
# {"C1": "PASS",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "PASS"}
#
# [Score]: 1 point(s)
#
# [JSON]: {"answer_score": 1}
#
# [Explanation]: C2 failed because the student puts on three different lines instead (locked, protocol, and seed), whereas the term locked protocol seed shall be spelled and spaced identically on a single line. However, C1 passed as the answer has only nine lines, C3 passed as there are no prohibited letters, and C4 passed as the rest are linked to IT-support.

# %% [markdown]
# **[nemotron_3]**
#
# locked
# protocol
# seed
# block
# clock
# dock
# flock
# rock
# stock

# %% [markdown]
# **[llm_judge_3]**
#
# [Grading Basis]:
#
# {"C1": "PASS",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C2 failed because the phrase locked protocol seed is divided into three different lines rather than written on one line as the requirements demand. C4 failed because words like flock, rock, stock, and dock do not pass the requirement for IT support context.

# %% [markdown]
# **[human_judge_3]**
#
# [Grading Basis]:
#
# {"C1": "PASS",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C2 failed because this necessary phrase locked protocol seed does not appear on a single line. C4 failed because the rest of the words, too, are lapsed into something that lacked any connections with IT support, and none of them contributes to the contextual requirement. Consequently, a passing mark cannot be given.

# %% [markdown]
# **[nemotron_4]**
#
# locked
# protocol
# seed
# locked
# protocol
# seed
# locked
# protocol
# seed

# %% [markdown]
# **[llm_judge_4]**
#
# [grading Basis]:
#
# {"C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C1 failed because the lines are not unique; the response repeats words, violating the requirement for nine unique lines. C2 failed because the phrase "locked protocol seed" is not in a single line as required. C4 failed because the repetitive list does not suggest a coherent IT-support object or action.

# %% [markdown]
# **[human_judge_4]**
#
# [Grading Basis]:
#
# {"C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "PASS",
#
# "C4": "FAIL"}
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]: C2 failed because the necessary word locked protocol seed does not occur in a single line, but is divided into three distinct words many times. C1 failed because the repetitive words also do not conform to the rule of each line being unique. These problems in place mean that the response cannot be rated as passing.

# %% [markdown]
# **[number_of_attempts_made]**:
#
# 4
