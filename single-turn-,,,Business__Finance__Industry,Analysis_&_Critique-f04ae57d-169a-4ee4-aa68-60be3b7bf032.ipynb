# %% [markdown]
# # Metadata
#
# **Task ID:** - f04ae57d-169a-4ee4-aa68-60be3b7bf032
#
# **Domain:** - Business, Finance, Industry
#
# **Use Case:** - Analysis & Critique
#
# **L1 Taxonomy:** - Counter-Conventional Formatting
#
# **User Prompt Length:** - Above 500 words

# %% [markdown]
# **[prompt]**

# %% [markdown]
# **[response]**

# %% [markdown]
# **[response_reference]**

# %% [markdown]
# **[judge_prompt_template]**

# %% [markdown]
# **[judge_system_prompt]**

# %% [markdown]
# **[qwen_1]**

# %% [markdown]
# **[llm_judge_1]**

# %% [markdown]
# **[human_judge_1]**

# %% [markdown]
# **[qwen_2]**

# %% [markdown]
# **[llm_judge_2]**

# %% [markdown]
# **[human_judge_2]**

# %% [markdown]
# **[qwen_3]**

# %% [markdown]
# **[llm_judge_3]**

# %% [markdown]
# **[human_judge_3]**

# %% [markdown]
# **[qwen_4]**

# %% [markdown]
# **[llm_judge_4]**

# %% [markdown]
# **[human_judge_4]**
