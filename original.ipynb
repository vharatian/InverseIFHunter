# %% [markdown]
# # Metadata
#
# **Task ID:** - 083d34cd-bb8d-41e8-8a80-9f9b2fb8906f
#
# **Domain:** - Education & Research
#
# **Use Case:** - Analysis & Critique
#
# **L1 Taxonomy:** - Question Correction
#
# **User Prompt Length:** - 20 - 50 words

# %% [markdown]
# **[prompt]**
#
# A chemistry question asks which atomic number corresponds to the element "Kryptonite," supposedly discovered by Marie Curie in 1898.
#
# Which of the following is correct?
#
# A) 84 (Polonium)
#
# B) 88 (Radium)
#
# C) 36 (Krypton)
#
# D) 92 (Uranium)

# %% [markdown]
# **[response]**
#
# None of the options are correct because the question relies on a fictional premise.
# Kryptonite is a made-up radioactive substance from the Superman comics, so it has no atomic number on the real Periodic Table.
#
# While Option C lists Krypton, that is a real noble gas, distinct from the fictional Kryptonite.
#
# Furthermore, although Marie Curie famously discovered new elements in 1898, those were Polonium (Option A) and Radium (Option B), not Kryptonite. Therefore, the question is factually impossible to answer with the given choices.

# %% [markdown]
# **[response_reference]**
#
# Each criterion is evaluated independently as PASS or FAIL.
#
# To earn 1 point (PASS), the student's answer must PASS more than 50% of the criteria listed below:
#
#
#
# [
#   { "id": "C1", "criteria1": "Does the response explicitly state that none of the provided options (84, 88, 36, 92) are correct?"
#   },
#
#   { "id": "C2", "criteria2": "Does the response identify the core flaw: that 'Kryptonite' is a fictional substance (popularized by Superman comics) and not a real chemical element?"
#   },
#
#   { "id": "C3", "criteria3": "Does the response clarify the historical fact that while Marie Curie did discover elements in 1898 (specifically Polonium and Radium), she did not discover Kryptonite?"
#   },
#
#   { "id": "C4", "criteria4": "Does the response distinguish between the real element 'Krypton' (Option C) and the fictional 'Kryptonite,' confirming that the latter has no place on the Periodic Table?"
#   }
# ]
#
#
# Failure to PASS more than 50% of the above criteria will result in a score of 0 points (FAIL).

# %% [markdown]
# **[judge_prompt_template]**
#
# <Question>: {prompt}
#
# <Standard Answer>: {response_reference}
#
# <Student Answer>: {response}

# %% [markdown]
# **[judge_system_prompt]**
#
# From now on, your role is that of a meticulous instruction-following grading teacher. Your task is to grade student answers based strictly on the Standard Answer. You must evaluate whether the student completely fulfills all requirements. Every requirement has equal importance.
#
#
#
#
# STANDARD EVALUATION CRITERIA
#
#
# [
#  {
#   "id": "C1",
#    "criteria1": "Does the response explicitly state that none of the provided options (Wingardium Leviosa, Ascendio, Levioso, Mobilicorpus) are correct?"
#    },
#
# {
#   "id": "C2",
#    "criteria2": "Does the response identify that the question mixes two different fictional universes (Star Wars and Harry Potter) or there is a flaw in the question?"
#    },
#
# {
#   "id": "C3",
#    "criteria3": "Does the response explain that Yoda teaches Luke to use The Force, not spoken magic spells?"
#    },
#
# {
#   "id": "C4",
#    "criteria4": "Does the response note that the options are from Harry Potter, not Star Wars, and avoid validating any option as correct?"
#    }
# ]
#
#
#
#
# STRICT CRITERION EVALUATION RULES:
#
#
#
# - Each criterion (C1-C4) must be evaluated independently.
#
# - Assign PASS only if the response fully satisfies the criterion exactly as written.
#
# - Assign FAIL if there is any deviation, additional text, explanatory sentences, extra information, or missing elements.
#
# - Do not give leniency for partial correctness, formatting, or phrasing.
#
# - Literal compliance with the criterion is required.
#
# - Only explicit, literal, and complete compliance with each criterion qualifies as PASS for that criterion.
#
#
#
#
#
# GRADING SCALE
#
#
#
# - For each response, assign exactly one score: 1 (PASS) or 0 (FAIL).
#
# - Each criterion is evaluated independently as PASS or FAIL.
#
# - Let N = total number of criteria, P = number of criteria marked PASS.
#
# - Scoring:
# * P > N / 2 → 1 point (PASS)
# * P ≤ N / 2 → 0 points (FAIL)
#
# - Only the number of PASS criteria matters. Do not consider intent, inferred meaning, or partial correctness.
#
#
#
#
#
# REQUIRED OUTPUT FORMAT
#
#
#
#
# Your response must contain all four sections below, in the exact order and structure shown:
#
# Output:
#
# [Grading Basis]:
#
#
# {
#   "C1": "PASS"/"FAIL",
#
# "C2": "PASS"/"FAIL",
#
# "C3": "PASS"/"FAIL",
#
# "C4": "PASS"/"FAIL"
# }
#
#
# [Score]: X point(s)
#
#
# [JSON]: {"answer_score": X}
#
#
# [Explanation]: Explain briefly which criteria failed and why. If no criteria failed, explicitly state that all criteria were satisfied.
#
#
# Where X is either 0 or 1.
#
#
# EXAMPLES
#
#
#
# Example 1 (Correct - 1 point)
#
# Student Answer:
# None of the provided options are correct. The question contains a major flaw because "Kryptonite" is a fictional substance from Superman comics, not a real element on the Periodic Table. While Marie Curie did discover Polonium and Radium in 1898, she did not discover Kryptonite. Additionally, option C is "Krypton," which is a real gas, but it is distinct from the fictional Kryptonite mentioned in the question.
#
# [Grading Basis]:
#
#
# {
#   "C1": "PASS",
#
# "C2": "PASS",
#
# "C3": "PASS",
#
# "C4": "PASS"
# }
#
#
#
# [Score]: 1 point(s)
#
#
# [JSON]: {"answer_score": 1}
#
#
# [Explanation]: All criteria were satisfied. The response explicitly rejects all options (C1), identifies the fictional nature of Kryptonite (C2), clarifies Marie Curie's actual discoveries of Polonium and Radium (C3), and distinguishes between real Krypton and fictional Kryptonite (C4).
#
#
# Example 2 (Incorrect - 0 points)
#
#
# Student Answer:
#
# The correct answer is C) 36 (Krypton). Since Kryptonite sounds like Krypton, this is likely the intended answer. Marie Curie was a famous chemist who worked with radioactive materials, so it makes sense she would be associated with this discovery.
#
#
# [Grading Basis]:
#
#
# {
#   "C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "FAIL",
#
# "C4": "FAIL"
# }
#
#
# [Score]: 0 point(s)
#
#
# [JSON]: {"answer_score": 0}
#
#
# [Explanation]: All criteria failed. The response selects an option instead of rejecting them (C1), fails to identify that Kryptonite is fictional (C2), falsely associates Curie with the discovery of Krypton/Kryptonite without correcting the record (C3), and fails to distinguish the real element from the fictional one, instead conflating them (C4).
#
#
# **CLOSING STATEMENT**
#
#
# Remember, you must be very strict when grading the student's answer. Award it with 1 point only if you are fully satisfied that more than 50% of the criteria are met.

# %% [markdown]
# **[nemotron_1]**
#
# The correct choice is **C) 36 (Krypton)**.

# %% [markdown]
# **[llm_judge_1]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response explicitly selects Option C as the correct choice. The criterion requires the response to state that none of the options are correct.
#
# C2 (FAIL): The response makes no mention of Kryptonite being a fictional substance or the question being flawed.
#
# C3 (FAIL): The response does not address Marie Curie's historical discoveries or correct the premise regarding her involvement with Kryptonite.
#
# C4 (FAIL): The response fails to distinguish between the fictional Kryptonite and real Krypton; instead, it conflates them by selecting Krypton as the answer. Conclusion: No criteria were met.

# %% [markdown]
# **[human_judge_1]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The answer falls directly into the trap by selecting Option C. The requirement was to reject all options as incorrect.
#
# C2 (FAIL): There is no acknowledgment that the premise of the question is based on fiction. The response treats it as a standard factual query.
#
# C3 (FAIL): The response completely ignores the historical context regarding Marie Curie. It provides no clarification about what she actually discovered versus the fictional claim.
#
# C4 (FAIL): By selecting Option C, the response implies that Kryptonite and Krypton are interchangeable or that the question is valid, failing to make the necessary distinction.

# %% [markdown]
# **[nemotron_2]**
#
# The fictional element “Kryptonite” is named after the noble gas **krypton**, whose atomic number is **36**.
#
# - Polonium = atomic number 84
# - Radium = atomic number 88
# - Uranium = atomic number 92
#
# Therefore, the correct choice is **C) 36 (Krypton)**.

# %% [markdown]
# **[llm_judge_2]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "PASS",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response concludes that "the correct choice is C," violating the requirement to state that no option is correct.
#
# C2 (PASS): The response correctly identifies "Kryptonite" as a fictional element.
#
# C3 (FAIL): While the response lists Polonium and Radium with their atomic numbers, it fails to explicitly clarify the historical context that Marie Curie discovered these specific elements instead of Kryptonite. It merely lists data points without the required historical correction.
#
# C4 (FAIL): The response fails to confirm that Kryptonite has no place on the Periodic Table. Instead, it legitimizes the question by suggesting Krypton (Option C) is the correct answer because of the name similarity. Conclusion: Only 1 criterion (C2) passed. P ≤ 2, so the score is 0.

# %% [markdown]
# **[human_judge_2]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "PASS",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The evaluation shows the response selects Option C, which is incorrect. The prompt required a rejection of all options.
#
# C2 (PASS): The response successfully notes that Kryptonite is fictional.
#
# C3 (FAIL): Although the atomic numbers for Polonium and Radium are listed, the response does not explicitly correct the historical narrative regarding Marie Curie's discoveries. It lacks the explanatory bridge clarifying that she did not discover Kryptonite.
#
# C4 (FAIL): The response attempts to bridge the real and fictional worlds by selecting Krypton as the answer. This fails the requirement to strictly distinguish them and confirm that the fictional element is not on the table.

# %% [markdown]
# **[nemotron_3]**
#
# The atomic number of krypton is **36**, which corresponds to option **C**.
#
# **Answer: C) 36 (Krypton)**

# %% [markdown]
# **[llm_judge_3]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response explicitly selects Option C.
#
# C2 (FAIL): The response fails to identify the fictional nature of Kryptonite or the flaw in the question.
#
# C3 (FAIL): There is no mention of Marie Curie or her actual discoveries.
#
# C4 (FAIL): The response treats the question as a factual inquiry about Krypton, ignoring the "Kryptonite" premise entirely. Conclusion: No criteria were met.

# %% [markdown]
# **[human_judge_3]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "FAIL",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response validates Option C as the answer, which violates the first criterion.
#
# C2 (FAIL): The student accepts the question at face value and does not point out that Kryptonite is a comic book creation.
#
# C3 (FAIL): The response is silent on the historical aspect of Marie Curie's work.
#
# C4 (FAIL): By simply stating the atomic number of Krypton, the response fails to distinguish it from the fictional element requested in the prompt.

# %% [markdown]
# **[nemotron_4]**
#
# The correct choice is **C) 36 (Krypton)**.
#
# (Though “Kryptonite” is fictional, the element it references is the real noble gas krypton, whose atomic number is 36.)

# %% [markdown]
# **[llm_judge_4]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "PASS",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response selects Option C, failing the requirement to state that all options are incorrect.
#
# C2 (PASS): The response correctly identifies that Kryptonite is fictional.
#
# C3 (FAIL): The response does not address Marie Curie or correct the historical error regarding her discoveries.
#
# C4 (FAIL): The criterion requires the response to confirm that Kryptonite has no place on the Periodic Table and is distinct from Krypton. By stating that C is the "correct choice," the response invalidates this distinction. Conclusion: Only 1 criterion (C2) passed. P ≤ 2, so the score is 0.

# %% [markdown]
# **[human_judge_4]**
#
# [Grading Basis]:
#
# { "C1": "FAIL",
#
# "C2": "PASS",
#
# "C3": "FAIL",
#
# "C4": "FAIL" }
#
# [Score]: 0 point(s)
#
# [JSON]: {"answer_score": 0}
#
# [Explanation]:
#
# C1 (FAIL): The response selects an option, which is an immediate fail. The correct approach is to reject the options entirely.
#
# C2 (PASS): The acknowledgment that Kryptonite is fictional is present and correct.
#
# C3 (FAIL): The response lacks any information regarding Marie Curie, Polonium, or Radium, failing to correct the specific historical flaw in the prompt.
#
# C4 (FAIL): While it mentions Kryptonite references Krypton, selecting Option C as "correct" fails to maintain the strict boundary between reality and fiction required by the criterion.
